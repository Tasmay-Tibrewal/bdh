# %%
# !git clone https://github.com/Tasmay-Tibrewal/bdh.git
# Out:
# Cloning into 'bdh'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 109 (delta 41), reused 35 (delta 22), pack-reused 51 (from 1)
# Receiving objects: 100% (109/109), 1011.88 KiB | 5.72 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# %cd /root/bdh
# %uv pip install -r requirements.txt
# Out:
# /root/bdh
# Using Python 3.12.6 environment at: /usr/local
# Resolved 70 packages in 199ms
# ⠙ Preparing packages... (0/10)
# ⠙ Preparing packages... (0/10)
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------     0 B/23.73 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# xxhash     ------------------------------     0 B/189.34 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# gitpython  ------------------------------     0 B/203.73 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# gitpython  ------------------------------ 14.84 KiB/203.73 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# multiprocess ------------------------------     0 B/146.76 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# gitpython  ------------------------------ 14.84 KiB/203.73 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# multiprocess ------------------------------ 16.00 KiB/146.76 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# gitpython  ------------------------------ 14.84 KiB/203.73 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# multiprocess ------------------------------ 16.00 KiB/146.76 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# gitpython  ------------------------------ 14.84 KiB/203.73 KiB
# sentry-sdk ------------------------------ 14.87 KiB/405.95 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# multiprocess ------------------------------ 16.00 KiB/146.76 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# gitpython  ------------------------------ 14.84 KiB/203.73 KiB
# sentry-sdk ------------------------------ 14.87 KiB/405.95 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# multiprocess ------------------------------ 16.00 KiB/146.76 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# gitpython  ------------------------------ 14.84 KiB/203.73 KiB
# sentry-sdk ------------------------------ 14.87 KiB/405.95 KiB
# datasets   ------------------------------ 16.00 KiB/500.26 KiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# multiprocess ------------------------------ 16.00 KiB/146.76 KiB
# xxhash     ------------------------------ 32.00 KiB/189.34 KiB
# gitpython  ------------------------------ 30.84 KiB/203.73 KiB
# sentry-sdk ------------------------------ 14.87 KiB/405.95 KiB
# datasets   ------------------------------ 77.27 KiB/500.26 KiB
# wandb      ------------------------------ 16.00 KiB/21.79 MiB
# ⠙ Preparing packages... (0/10)
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# dill       ------------------------------ 62.88 KiB/116.86 KiB
# multiprocess ------------------------------ 48.00 KiB/146.76 KiB
# gitpython  ------------------------------ 78.61 KiB/203.73 KiB
# sentry-sdk ------------------------------ 30.87 KiB/405.95 KiB
# datasets   ------------------------------ 141.27 KiB/500.26 KiB
# wandb      ------------------------------ 32.00 KiB/21.79 MiB
# ⠙ Preparing packages... (0/10)
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# dill       ------------------------------ 77.49 KiB/116.86 KiB
# multiprocess ------------------------------ 63.43 KiB/146.76 KiB
# gitpython  ------------------------------ 110.61 KiB/203.73 KiB
# sentry-sdk ------------------------------ 46.87 KiB/405.95 KiB
# datasets   ------------------------------ 188.88 KiB/500.26 KiB
# wandb      ------------------------------ 64.00 KiB/21.79 MiB
# ⠙ Preparing packages... (0/10)
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# dill       ------------------------------ 77.49 KiB/116.86 KiB
# multiprocess ------------------------------ 63.43 KiB/146.76 KiB
# gitpython  ------------------------------ 110.61 KiB/203.73 KiB
# sentry-sdk ------------------------------ 62.87 KiB/405.95 KiB
# datasets   ------------------------------ 221.27 KiB/500.26 KiB
# wandb      ------------------------------ 64.00 KiB/21.79 MiB
# ⠙ Preparing packages... (0/10)
# dill       ------------------------------ 94.88 KiB/116.86 KiB
# multiprocess ------------------------------ 143.43 KiB/146.76 KiB
# gitpython  ------------------------------ 158.61 KiB/203.73 KiB
# sentry-sdk ------------------------------ 124.38 KiB/405.95 KiB
# datasets   ------------------------------ 237.27 KiB/500.26 KiB
# wandb      ------------------------------ 80.00 KiB/21.79 MiB
# ⠙ Preparing packages... (0/10)
# dill       ------------------------------ 110.88 KiB/116.86 KiB
# multiprocess ------------------------------ 143.43 KiB/146.76 KiB
# gitpython  ------------------------------ 203.73 KiB/203.73 KiB
# sentry-sdk ------------------------------ 156.38 KiB/405.95 KiB
# datasets   ------------------------------ 301.27 KiB/500.26 KiB
# wandb      ------------------------------ 96.00 KiB/21.79 MiB
# ⠙ Preparing packages... (0/10)
# dill       ------------------------------ 110.88 KiB/116.86 KiB
# multiprocess ------------------------------ 143.43 KiB/146.76 KiB
# sentry-sdk ------------------------------ 156.38 KiB/405.95 KiB
# datasets   ------------------------------ 301.27 KiB/500.26 KiB
# wandb      ------------------------------ 96.00 KiB/21.79 MiB
# ⠙ Preparing packages... (0/10)
# dill       ------------------------------ 116.86 KiB/116.86 KiB
# sentry-sdk ------------------------------ 172.38 KiB/405.95 KiB
# datasets   ------------------------------ 317.27 KiB/500.26 KiB
# wandb      ------------------------------ 96.00 KiB/21.79 MiB
# ⠙ Preparing packages... (0/10)
# sentry-sdk ------------------------------ 172.38 KiB/405.95 KiB
# datasets   ------------------------------ 317.27 KiB/500.26 KiB
# wandb      ------------------------------ 96.00 KiB/21.79 MiB
# ⠙ Preparing packages... (0/10)
# sentry-sdk ------------------------------ 236.38 KiB/405.95 KiB
# datasets   ------------------------------ 349.27 KiB/500.26 KiB
# wandb      ------------------------------ 192.00 KiB/21.79 MiB
# ⠹ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 252.38 KiB/405.95 KiB
# datasets   ------------------------------ 349.27 KiB/500.26 KiB
# wandb      ------------------------------ 208.00 KiB/21.79 MiB
# ⠹ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 252.38 KiB/405.95 KiB
# datasets   ------------------------------ 349.27 KiB/500.26 KiB
# wandb      ------------------------------ 208.00 KiB/21.79 MiB
# ⠹ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 284.38 KiB/405.95 KiB
# datasets   ------------------------------ 365.27 KiB/500.26 KiB
# wandb      ------------------------------ 224.00 KiB/21.79 MiB
# ⠸ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 300.38 KiB/405.95 KiB
# datasets   ------------------------------ 365.27 KiB/500.26 KiB
# wandb      ------------------------------ 224.00 KiB/21.79 MiB
# ⠸ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 300.38 KiB/405.95 KiB
# datasets   ------------------------------ 381.27 KiB/500.26 KiB
# wandb      ------------------------------ 225.89 KiB/21.79 MiB
# ⠸ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 316.38 KiB/405.95 KiB
# datasets   ------------------------------ 397.27 KiB/500.26 KiB
# wandb      ------------------------------ 2.22 MiB/21.79 MiB
# ⠸ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 316.38 KiB/405.95 KiB
# datasets   ------------------------------ 397.27 KiB/500.26 KiB
# wandb      ------------------------------ 4.17 MiB/21.79 MiB
# ⠼ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 316.38 KiB/405.95 KiB
# datasets   ------------------------------ 413.27 KiB/500.26 KiB
# wandb      ------------------------------ 6.22 MiB/21.79 MiB
# ⠼ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 316.38 KiB/405.95 KiB
# datasets   ------------------------------ 413.27 KiB/500.26 KiB
# wandb      ------------------------------ 7.88 MiB/21.79 MiB
# ⠼ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 332.38 KiB/405.95 KiB
# datasets   ------------------------------ 461.27 KiB/500.26 KiB
# wandb      ------------------------------ 10.20 MiB/21.79 MiB
# ⠼ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 332.38 KiB/405.95 KiB
# datasets   ------------------------------ 477.27 KiB/500.26 KiB
# wandb      ------------------------------ 12.16 MiB/21.79 MiB
# ⠼ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 332.38 KiB/405.95 KiB
# datasets   ------------------------------ 477.27 KiB/500.26 KiB
# wandb      ------------------------------ 13.20 MiB/21.79 MiB
# ⠴ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 332.38 KiB/405.95 KiB
# datasets   ------------------------------ 477.27 KiB/500.26 KiB
# wandb      ------------------------------ 15.83 MiB/21.79 MiB
# ⠴ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 332.38 KiB/405.95 KiB
# datasets   ------------------------------ 493.27 KiB/500.26 KiB
# wandb      ------------------------------ 16.29 MiB/21.79 MiB
# ⠴ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 332.38 KiB/405.95 KiB
# wandb      ------------------------------ 18.23 MiB/21.79 MiB
# ⠴ Preparing packages... (6/10)
# sentry-sdk ------------------------------ 332.38 KiB/405.95 KiB
# wandb      ------------------------------ 18.24 MiB/21.79 MiB
# ⠦ Preparing packages... (7/10)
# sentry-sdk ------------------------------ 332.38 KiB/405.95 KiB
# wandb      ------------------------------ 19.79 MiB/21.79 MiB
# ⠦ Preparing packages... (7/10)
# sentry-sdk ------------------------------ 348.38 KiB/405.95 KiB
# wandb      ------------------------------ 19.84 MiB/21.79 MiB
# ⠦ Preparing packages... (7/10)
# sentry-sdk ------------------------------ 348.38 KiB/405.95 KiB
# wandb      ------------------------------ 19.86 MiB/21.79 MiB
# ⠦ Preparing packages... (7/10)
# sentry-sdk ------------------------------ 364.38 KiB/405.95 KiB
# wandb      ------------------------------ 19.87 MiB/21.79 MiB
# ⠦ Preparing packages... (7/10)
# wandb      ------------------------------ 19.90 MiB/21.79 MiB
# ⠦ Preparing packages... (7/10)
# wandb      ------------------------------ 19.97 MiB/21.79 MiB
# ⠧ Preparing packages... (8/10)
# wandb      ------------------------------ 20.26 MiB/21.79 MiB
# ⠧ Preparing packages... (8/10)
# wandb      ------------------------------ 20.60 MiB/21.79 MiB
# ⠧ Preparing packages... (8/10)
# wandb      ------------------------------ 20.79 MiB/21.79 MiB
# ⠧ Preparing packages... (8/10)
# ⠧ Preparing packages... (8/10)
# Prepared 10 packages in 1.42s
# Installed 10 packages in 287ms
#  + datasets==4.4.2
#  + dill==0.4.0
#  + gitdb==4.0.12
#  + gitpython==3.1.46
#  + multiprocess==0.70.18
#  + pyarrow==22.0.0
#  + sentry-sdk==2.49.0
#  + smmap==5.0.2
#  + wandb==0.24.0
#  + xxhash==3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %uv pip install wandb -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd /root/bdh
# Out:
# /root/bdh

# %%
import os
os.environ["WANDB_API_KEY"] = "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"

# %%
import wandb
wandb.login()

# %%
# !git checkout -- bdh.py

# %%
# !bash -lc 'git pull > git_pull_logs.txt 2>&1'

# %%
# !python train.py

# %%
# %cd /root/bdh

# %%
# !python steps_per_epoch.py --data-bin data/tinystories_v2_gpt4/train.bin --batch-size 64 --block-size 1024
# Out:
# 33412

# %%
# !python pretrain_tinystories.py --model-size 25m --wandb-entity keshavtibrewal2 --batch-size 64 --block-size 1024 --eval-interval 250 --max-steps 22000
# Out:
# Using device: cuda dtype=bfloat16 params=25,296,896
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: keshavtibrewal2 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.24.0
# wandb: Run data is saved locally in /root/bdh/wandb/run-20260114_091911-c4njqzvh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run avid-armadillo-6
# wandb: ⭐️ View project at https://wandb.ai/keshavtibrewal2/bdh-pretrain
# wandb: 🚀 View run at https://wandb.ai/keshavtibrewal2/bdh-pretrain/runs/c4njqzvh
# step 50 train_loss=3.0796 time=39.7s
# step 100 train_loss=2.4484 time=39.2s
# step 150 train_loss=2.3446 time=39.2s
# step 200 train_loss=2.1868 time=39.1s
# step 250 train_loss=1.6488 time=39.1s
# step 250 val_loss=1.4041
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 300 train_loss=1.2744 time=54.7s
# step 350 train_loss=1.0852 time=39.1s
# step 400 train_loss=0.9738 time=39.1s
# step 450 train_loss=0.9140 time=39.1s
# step 500 train_loss=0.8611 time=39.1s
# step 500 val_loss=0.8277
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 550 train_loss=0.8239 time=54.6s
# step 600 train_loss=0.7873 time=39.0s
# step 650 train_loss=0.7636 time=39.0s
# step 700 train_loss=0.7425 time=39.0s
# step 750 train_loss=0.7232 time=39.0s
# step 750 val_loss=0.7050
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 800 train_loss=0.7054 time=54.6s
# step 850 train_loss=0.6890 time=39.0s
# step 900 train_loss=0.6700 time=39.0s
# step 950 train_loss=0.6571 time=39.0s
# step 1000 train_loss=0.6395 time=39.0s
# step 1000 val_loss=0.6275
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 1050 train_loss=0.6298 time=54.9s
# step 1100 train_loss=0.6162 time=39.0s
# step 1150 train_loss=0.6056 time=39.0s
# step 1200 train_loss=0.5967 time=39.0s
# step 1250 train_loss=0.5888 time=39.0s
# step 1250 val_loss=0.5742
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 1300 train_loss=0.5803 time=54.5s
# step 1350 train_loss=0.5676 time=39.0s
# step 1400 train_loss=0.5648 time=38.9s
# step 1450 train_loss=0.5578 time=38.9s
# step 1500 train_loss=0.5504 time=38.9s
# step 1500 val_loss=0.5372
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 1550 train_loss=0.5463 time=54.5s
# step 1600 train_loss=0.5404 time=38.9s
# step 1650 train_loss=0.5352 time=38.9s
# step 1700 train_loss=0.5313 time=38.9s
# step 1750 train_loss=0.5254 time=38.9s
# step 1750 val_loss=0.5164
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 1800 train_loss=0.5206 time=54.5s
# step 1850 train_loss=0.5180 time=38.9s
# step 1900 train_loss=0.5143 time=38.9s
# step 1950 train_loss=0.5141 time=38.9s
# step 2000 train_loss=0.5116 time=38.9s
# step 2000 val_loss=0.4993
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 2050 train_loss=0.5036 time=54.8s
# step 2100 train_loss=0.5020 time=38.9s
# step 2150 train_loss=0.5007 time=38.9s
# step 2200 train_loss=0.4975 time=38.9s
# step 2250 train_loss=0.4940 time=38.9s
# step 2250 val_loss=0.4872
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 2300 train_loss=0.4938 time=54.4s
# step 2350 train_loss=0.4918 time=38.9s
# step 2400 train_loss=0.4909 time=38.9s
# step 2450 train_loss=0.4866 time=38.9s
# step 2500 train_loss=0.4849 time=38.9s
# step 2500 val_loss=0.4742
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 2550 train_loss=0.4817 time=54.5s
# step 2600 train_loss=0.4786 time=38.9s
# step 2650 train_loss=0.4796 time=38.9s
# step 2700 train_loss=0.4758 time=38.9s
# step 2750 train_loss=0.4728 time=38.9s
# step 2750 val_loss=0.4665
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 2800 train_loss=0.4732 time=54.4s
# step 2850 train_loss=0.4715 time=38.9s
# step 2900 train_loss=0.4688 time=38.9s
# step 2950 train_loss=0.4666 time=38.9s
# step 3000 train_loss=0.4682 time=38.9s
# step 3000 val_loss=0.4577
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 3050 train_loss=0.4681 time=54.8s
# step 3100 train_loss=0.4653 time=38.9s
# step 3150 train_loss=0.4617 time=38.9s
# step 3200 train_loss=0.4610 time=38.9s
# step 3250 train_loss=0.4624 time=38.9s
# step 3250 val_loss=0.4529
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 3300 train_loss=0.4594 time=54.4s
# step 3350 train_loss=0.4565 time=38.9s
# step 3400 train_loss=0.4576 time=38.9s
# step 3450 train_loss=0.4566 time=38.9s
# step 3500 train_loss=0.4533 time=38.9s
# step 3500 val_loss=0.4475
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 3550 train_loss=0.4511 time=54.4s
# step 3600 train_loss=0.4500 time=38.9s
# step 3650 train_loss=0.4468 time=38.9s
# step 3700 train_loss=0.4514 time=38.9s
# step 3750 train_loss=0.4482 time=38.9s
# step 3750 val_loss=0.4392
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 3800 train_loss=0.4498 time=54.4s
# step 3850 train_loss=0.4483 time=38.9s
# step 3900 train_loss=0.4462 time=38.9s
# step 3950 train_loss=0.4438 time=38.9s
# step 4000 train_loss=0.4442 time=38.9s
# step 4000 val_loss=0.4360
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt
# step 4050 train_loss=0.4433 time=54.8s
# step 4100 train_loss=0.4429 time=38.9s
# step 4150 train_loss=0.4391 time=38.9s
# step 4200 train_loss=0.4386 time=38.9s
# step 4250 train_loss=0.4412 time=38.9s
# step 4250 val_loss=0.4343
# saved best checkpoint to checkpoints/pretrain_tinystories/ckpt_best.pt

# %%
# !bash -lc 'python infer.py --checkpoint checkpoints/pretrain_tinystories/ckpt_best.pt --prompt "Hello my name is harry " --max-new-tokens 1024 > output.txt 2>&1'

# %%
# !bash -lc 'python pretrain_tinystories.py --model-size 25m --wandb-entity keshavtibrewal2 --batch-size 64 --grad-acc-steps 8 --block-size 1024 --eval-interval 50 --max-steps 11000 --resume-from /root/bdh/checkpoints/pretrain_tinystories/ckpt_best.pt > train_run2_logs.txt 2>&1'
